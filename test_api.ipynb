# %%
from cmschina_tianyan.session import CmsSession

dataset = CmsSession.init(appId="cb632213cf764a019b32f8cc9d2040b7", appSecret="b23700b9fbf0090709c7b72ac0fdcb390cd19cc663bcf1c7a07c12b8c32bf377")
data = dataset.get_data(
        '''
        select TRADE_DT from wind_admin.AShareEODDerivativeIndicator limit 10000
        ''')
print(data)
# Out:
# [2022-09-28T15:22:25.207868+0800] [42229] [INFO] [session.py] [63] PROD Env Init Completed!
# [2022-09-28T15:22:25.208073+0800] [42229] [ERROR] [tianyan_provider.py] [134] Exception: TypeError("unsupported operand type(s) for -: 'NoneType' and 'int'")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/4y/tm0f5s2n00s3g71c6qrvd0bh0000gn/T/ipykernel_42229/3416591596.py in <module>
#       2
#       3 dataset = CmsSession.init(appId="cb632213cf764a019b32f8cc9d2040b7", appSecret="b23700b9fbf0090709c7b72ac0fdcb390cd19cc663bcf1c7a07c12b8c32bf377")
# ----> 4 data = dataset.get_data(
#       5         '''
#       6         select TRADE_DT from wind_admin.AShareEODDerivativeIndicator limit 10000
#
# ~/opt/anaconda3/lib/python3.9/site-packages/cmschina_tianyan/data/dataset.py in get_data(self, query, timeout)
#      87         :return: A Dataframe of the requested data
#      88         """
# ---> 89         data = self.provider.query_data(query, self.id, timeout)
#      90
#      91         return data
#
# ~/opt/anaconda3/lib/python3.9/site-packages/cmschina_tianyan/api/cms/tianyan_provider.py in query_data(cls, sqlquery, dataset_id, timeout)
#      88
#      89             ## _logger.debug('query data with query = {1}'.format(sqlquery))
# ---> 90             if cls._is_token_error():
#      91                 with cls.__lock:
#      92                     if cls._is_token_error():
#
# ~/opt/anaconda3/lib/python3.9/site-packages/cmschina_tianyan/api/cms/tianyan_provider.py in _is_token_error(cls, var)
#      29             return True
#      30         current_sys_time = int(time.time())
# ---> 31         if current_sys_time > cls.__expires - var:
#      32             return True
#      33         else:
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'

# %%
from WindPy import *

#Wind API 使用W账户密码登录
w.start() 

#return True and then can go to next operation.
w.isconnected()

import pandas as pd
wdata = w.wst("600000.SH", "last,volume,bid10,bid9,bid8,bid7,bid6,bid5,bid4,bid3,bid2,bid1,ask10,ask9,ask8,ask7,ask6,ask5,ask4,ask3,ask2,ask1", 
"2022-08-01 09:00:00", "2022-09-28 10:30:51", "",usedf=True)[1]
wdata
# Out:
#                      LAST     VOLUME  BID10  BID9  BID8  BID7  BID6  BID5  \
# 2022-09-19 09:15:03  7.15        NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 2022-09-19 09:15:06  7.15        NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 2022-09-19 09:15:09  7.15        NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 2022-09-19 09:15:12  7.15        NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 2022-09-19 09:15:15  7.15        NaN    NaN   NaN   NaN   NaN   NaN   NaN
# ...                   ...        ...    ...   ...   ...   ...   ...   ...
# 2022-09-28 10:30:37  7.07  7352894.0    NaN   NaN   NaN   NaN   NaN  7.02
# 2022-09-28 10:30:40  7.06  7355194.0    NaN   NaN   NaN   NaN   NaN  7.02
# 2022-09-28 10:30:43  7.06  7359094.0    NaN   NaN   NaN   NaN   NaN  7.02
# 2022-09-28 10:30:46  7.06  7371694.0    NaN   NaN   NaN   NaN   NaN  7.02
# 2022-09-28 10:30:49  7.06  7374194.0    NaN   NaN   NaN   NaN   NaN  7.02
#
#                      BID4  BID3  ...  ASK10  ASK9  ASK8  ASK7  ASK6  ASK5  \
# 2022-09-19 09:15:03   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 2022-09-19 09:15:06   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 2022-09-19 09:15:09   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 2022-09-19 09:15:12   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 2022-09-19 09:15:15   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# ...                   ...   ...  ...    ...   ...   ...   ...   ...   ...
# 2022-09-28 10:30:37  7.03  7.04  ...    NaN   NaN   NaN   NaN   NaN  7.11
# 2022-09-28 10:30:40  7.03  7.04  ...    NaN   NaN   NaN   NaN   NaN  7.11
# 2022-09-28 10:30:43  7.03  7.04  ...    NaN   NaN   NaN   NaN   NaN  7.11
# 2022-09-28 10:30:46  7.03  7.04  ...    NaN   NaN   NaN   NaN   NaN  7.11
# 2022-09-28 10:30:49  7.03  7.04  ...    NaN   NaN   NaN   NaN   NaN  7.11
#
#                      ASK4  ASK3  ASK2  ASK1
# 2022-09-19 09:15:03   NaN   NaN   NaN  7.15
# 2022-09-19 09:15:06   NaN   NaN   NaN  7.15
# 2022-09-19 09:15:09   NaN   NaN   NaN  7.15
# 2022-09-19 09:15:12   NaN   NaN   NaN  7.15
# 2022-09-19 09:15:15   NaN   NaN   NaN  7.15
# ...                   ...   ...   ...   ...
# 2022-09-28 10:30:37   7.1  7.09  7.08  7.07
# 2022-09-28 10:30:40   7.1  7.09  7.08  7.07
# 2022-09-28 10:30:43   7.1  7.09  7.08  7.07
# 2022-09-28 10:30:46   7.1  7.09  7.08  7.07
# 2022-09-28 10:30:49   7.1  7.09  7.08  7.07
#
# [32650 rows x 22 columns]
